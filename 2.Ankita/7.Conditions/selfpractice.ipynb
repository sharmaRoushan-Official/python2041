# %%
num= int(input("enter number"))
if num>0:
    print("possitive")
elif num<0:
    print("negative")
else:
    print("zero")
# Out:
# enter number 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 num=input("enter number")
# ----> 2 if num>0:
#       3     print("possitive")
#       4 elif num<0:
#       5     print("negative")
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
num= int(input("enter number"))
if num>0:
    print("possitive")
elif num<0:
    print("negative")
else:
    print("zero")
# Out:
# enter number 3
# possitive

# %%
##2. Write a Python program to check if a number is *even* or *odd*.
num=int(input("enter number"))
if num%2==0:
    print("number is even:")
else:
    print("number is odd:")
# Out:
# enter number 4
# number is even:

# %%
num=int(input("enter number"))
if num%2==0:
    print("number is even:")
else:
    print("number is odd:")
# Out:
# enter number 7
# number is odd:

# %%
##3. Write a Python program to check if a person is *eligible to vote* (age ≥ 18).
age=int(input("enter age"))
if age>=18:
    print("eligible to vote:")
elif age<=18:
    print("not eligible to vote")
else:
    print("not vallied for vote")
# Out:
#   Cell In[5], line 7
#     else
#     ^
# SyntaxError: invalid syntax

# %%
age=int(input("enter age"))
if age>=18:
    print("eligible to vote:")
elif age<=18:
    print("not eligible to vote")
else:
    print("not vallied for vote")
# Out:
# enter age 18
# eligible to vote:

# %%
age=int(input("enter age"))
if age>=18:
    print("eligible to vote:")
elif age<=18:
    print("not eligible to vote")
else:
    print("not vallied for vote")
# Out:
# enter age 12
# not eligible to vote

# %%
age=int(input("enter age"))
if age>=18:
    print("eligible to vote:")
elif age<=18:
    print("not eligible to vote")
else:
    print("not vallied for vote")
# Out:
# enter age 0
# not eligible to vote

# %%
##4. Write a Python program to find the *largest of two numbers*.
num1=int(input("enter 1st number"))
num2=int(input("enter 2nd number"))
if (num1>num2):
    print("lagest number")
else:
    print("smallest number")
# Out:
# enter 1st number 12
# enter 2nd number 20
# smallest number

# %%
num1=int(input("enter 1st number"))
num2=int(input("enter 2nd number"))
if (num1>num2):
    print("lagest number")
else:
    print("smallest number")
# Out:
# enter 1st number 100
# enter 2nd number 10
# lagest number

# %%
##5. Write a Python program to check whether a number is *divisible by 5* or not.
num=int(input("enter number:"))
if num%5==0:
    print("divisible by 5")
else:
    print("noit divisible by 5")
# Out:
# enter number: 10
# divisible by 5

# %%
num=int(input("enter number:"))
if num%5==0:
    print("divisible by 5")
else:
    print("noit divisible by 5")
# Out:
# enter number: 4
# noit divisible by 5

# %%
##6. Write a Python program to check if a number is *a multiple of both 3 and 5*.
num=int(input("enter number:"))
if num %3==0 and num%5==0:
    print(" multiply of 3 &5:")
else:
    print("not multiply by 3&5:")
# Out:
#   Cell In[13], line 3
#     if num%==3 and num%==5:
#           ^
# SyntaxError: invalid syntax

# %%
num=int(input("enter number:"))
if num%3==0 and num%5==0:
    print(" multiply of 3 &5:")
else:
    print("not multiply by 3&5:")
# Out:
# enter number: 15
#  multiply of 3 &5:

# %%
num=int(input("enter number:"))
if num%3==0 and num%5==0:
    print(" multiply of 3 &5:")
else:
    print("not multiply by 3&5:")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 num=int(input("enter number:"))
#       2 if num%3==0 and num%5==0:
#       3     print(" multiply of 3 &5:")
#       4 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
##7. Write a Python program to check whether a character is a *vowel or consonant*.
str=int("enter value")
if str=="aeiou":
    print("str is vovel")
else:
    print("its consonants:")

# %%
str=int("enter value")
if str=="aeiou":
    print("str is vovel")
else:
    print("its consonants:")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 str=int("enter value")
#       2 if str=="aeiou":
#       3     print("str is vovel")
#       4 else:
#
# ValueError: invalid literal for int() with base 10: 'enter value'

# %%
char=str(input("enter chracter:"))
if char=="aeiou":
    print("str is vovel")
else:
    print("consonants:")
# Out:
# enter chracter: u
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 char=int(input("enter chracter:"))
#       2 if char=="aeiou":
#       3     print("str is vovel")
#       4 else:
#
# ValueError: invalid literal for int() with base 10: 'u'

# %%
char=str(input("enter chracter:"))
if str=="aeiou":
    print("str is vovel")
else:
    print("consonants:")
# Out:
# enter chracter: a
# consonants:

# %%
char=input("enter chracter:"))
if char=="aeiou":
    print("str is vovel")
else:
    print("consonants:")
# Out:
# enter chracter: i
# consonants:

# %%
char=input("enter chracter:"))
if char=="aeiou":
    print("str is vovel")
else:
    print("consonants:")
# Out:
#   Cell In[20], line 1
#     char=input("enter chracter:"))
#                                  ^
# SyntaxError: unmatched ')'

# %%
char=input("enter chracter:")
if char=="aeiou":
    print("str is vovel")
else:
    print("consonants:")
# Out:
# enter chracter: a
# consonants:

# %%
char=input("enter chracter:")
if char is "aeiou":
    print("str is vovel")
else:
    print("consonants:")
# Out:
# enter chracter: e
# consonants:

# %%
ch=input("enter chracter:").lower()
if ch in "aeiou":
    print("is vowel")
else:
    print("is consonants:")
# Out:
# <>:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# enter chracter: a
# consonants:
# C:\Users\User\AppData\Local\Temp\ipykernel_10816\1340252206.py:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if char is "aeiou":

# %%
ch=input("enter chracter:").lower()
if ch in "aeiou":
    print("is vowel")
else:
    print("is consonants:")
# Out:
# enter chracter: a
# is vowel

# %%
ch=input("enter chracter:").lower()
if ch in "aeiou":
    print("is vowel")
else:
    print("is consonants:")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ch=input("enter chracter:").lower()
#       2 if ch in "aeiou":
#       3     print("is vowel")
#       4 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
##8. Write a Python program to determine whether a given year is a *leap year* or not.
year=input("enter year:")
if year%400==0 or year%4==0:
    print("its leap year:")
else:
    print("not leap year")
# Out:
# enter year: 2024
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 ##8. Write a Python program to determine whether a given year is a *leap year* or not.
#       2 name=input("enter year:")
# ----> 3 if year%400==0 or year%4==0:
#       4     print("its leap year:")
#       5 else:
#       6     print("not leap year")
#
# NameError: name 'year' is not defined

# %%
year=input("enter year:")
if year%4==0 or year%400==0:
    print("leap year")
else:
    print("not leap year")
# Out:
# enter year: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 year=input("enter year:")
# ----> 2 if year%4==0 or year%400==0:
#       3     print("leap year")
#       4 else:
#       5     print("not leap year")
#
# TypeError: not all arguments converted during string formatting

# %%
##9. Write a Python program to check if a number is *within the range 1–100*.
num=int(input("enter number"))
if 1>=100:
    print("within range:")
else:
    print("without range:")

# %%
num=int(input("enter number"))
if 1>=100:
    print("within range:")
else:
    print("without range:")
# Out:
# enter number 99
# without range:

# %%
num=int(input("enter number"))
if 1>=100 and 1>=100:
    print("within range:")
else:
    print("without range:")
# Out:
# enter number 99
# without range:

# %%
num=int(input("enter number"))
if 1>=100 num 1<=100:
    print("within range:")
else:
    print("without range:")
# Out:
#   Cell In[32], line 2
#     if 1>=100 num 1<=100:
#               ^
# SyntaxError: invalid syntax

# %%
## 10. Write a Python program to check if a person is a *child (≤12), **teenager (13–19), or **adult (≥20)*.
num=int(input("enter person:"))
if person<=12:
    print("its child:")
elif person<13 and person<=19:
    print("its teenager" )
